# %%
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/anilyesilkaya/cepGPT/refs/heads/main/data/nutuk_veri_seti/nutuk.txt

# %%
with open("nutuk.txt", "r", encoding="utf-8") as f:
    text = f.read()
print(text[0:500])
# Out:
# NUTUK
#
# Mustafa Kemal ATATÜRK
#
# Samsun’a Çıktığım Gün Genel Durum ve Görünüş
# 1919 yılı Mayısının Ondokuzuncu Günü Samsun’a Çıktım. Ülkenin Genel Durumu ve Görünüşü Şöyleydi: Osmanlı Devleti’nin içinde bulunduğu grup, I. Dünya Savaşı‘nda yenilmiş, Osmanlı Ordusu her tarafta zedelenmiş, şartları ağır bir ateşkes anlaşması imzalanmış, Büyük Savaş’ın uzun yılları boyunca millet yorgun ve fakir bir durumda. Milleti ve memleketi I. Dünya Savaşı‘na sürükleyenler, kendi hayatlarını kurtarma kaygısına düşe

# %%
# Characters dictionary
chars = sorted(set(list(text)))
print("".join(chars))
print(f"\nVocabulary length: {len(chars)}")
# Out:
#  !%(),-./0123456789:;?ABCDEFGHIJKLMNOPRSTUVWXYZabcdefghijklmnopqrstuvwxyz ÂÇÖÜâçéîöûüĞğİıŞş‘’“”
#
# Vocabulary length: 96

# %%
# Character histogram
char_freq = {}
for c in text:
    if c not in char_freq.keys():
        char_freq[c] = 1
    else:
        char_freq[c] += 1

# %%
char_freq
# Out:
# {'N': 685,
#  'U': 98,
#  'T': 1735,
#  'K': 3363,
#  '\n': 5012,
#  'M': 3451,
#  'u': 39803,
#  's': 28686,
#  't': 40082,
#  'a': 116352,
#  'f': 6511,
#  ' ': 160853,
#  'e': 111150,
#  'm': 41249,
#  'l': 76003,
#  'A': 2480,
#  'Ü': 101,
#  'R': 992,
#  'S': 1774,
#  'n': 77417,
#  '’': 7155,
#  'Ç': 303,
#  'ı': 47030,
#  'k': 45186,
#  'ğ': 11050,
#  'G': 954,
#  'ü': 18950,
#  'D': 1116,
#  'r': 72712,
#  'v': 15307,
#  'ö': 7415,
#  'ş': 19627,
#  '1': 1919,
#  '9': 1127,
#  'y': 28915,
#  'O': 878,
#  'd': 45601,
#  'o': 19852,
#  'z': 15418,
#  'c': 9692,
#  '.': 10924,
#  'i': 95535,
#  'Ş': 367,
#  ':': 1042,
#  'ç': 8040,
#  'b': 23962,
#  'g': 13694,
#  'p': 5532,
#  ',': 14165,
#  'I': 59,
#  '‘': 655,
#  'h': 10065,
#  'B': 6058,
#  'H': 2371,
#  'â': 3074,
#  'V': 424,
#  'F': 782,
#  'P': 1956,
#  'û': 944,
#  'Y': 947,
#  'İ': 2544,
#  ';': 342,
#  'î': 1606,
#  'j': 122,
#  '5': 246,
#  'Ö': 180,
#  '-': 1200,
#  'E': 2097,
#  'Z': 192,
#  'C': 992,
#  '4': 237,
#  '/': 99,
#  '(': 250,
#  '2': 1231,
#  ')': 323,
#  '3': 434,
#  'L': 150,
#  'Â': 33,
#  'w': 25,
#  '7': 155,
#  '0': 535,
#  '6': 137,
#  '“': 1255,
#  '”': 1237,
#  '!': 171,
#  '?': 441,
#  '8': 184,
#  'J': 37,
#  'W': 19,
#  'x': 3,
#  'X': 1,
#  'q': 1,
#  '\xa0': 3,
#  'é': 2,
#  'Ğ': 3,
#  '%': 1}

# %%
def calculate_freq(d, sort=True, norm=True, replace_space=True):
    # Calculates relative frequencies for an unsorted dict
    if sort:
        d = dict(sorted(d.items(), key = lambda item:item[1], reverse=True))
    if replace_space:
        keys = [key if key !=" " else "<SPC>" for key in d.keys()]
    else:
        keys = [k for k in d.keys()]
    if norm:
        vals = [100*val/sum(d.values()) for val in d.values()]
    else:
        vals = [val for val in d.values()]
    return (d, keys, vals)

# %%
# Sorted char frequencies
(sorted_char_freq, hist_chars, hist_freqs) = calculate_freq(char_freq)
sorted_char_freq
# Out:
# {' ': 160853,
#  'a': 116352,
#  'e': 111150,
#  'i': 95535,
#  'n': 77417,
#  'l': 76003,
#  'r': 72712,
#  'ı': 47030,
#  'd': 45601,
#  'k': 45186,
#  'm': 41249,
#  't': 40082,
#  'u': 39803,
#  'y': 28915,
#  's': 28686,
#  'b': 23962,
#  'o': 19852,
#  'ş': 19627,
#  'ü': 18950,
#  'z': 15418,
#  'v': 15307,
#  ',': 14165,
#  'g': 13694,
#  'ğ': 11050,
#  '.': 10924,
#  'h': 10065,
#  'c': 9692,
#  'ç': 8040,
#  'ö': 7415,
#  '’': 7155,
#  'f': 6511,
#  'B': 6058,
#  'p': 5532,
#  '\n': 5012,
#  'M': 3451,
#  'K': 3363,
#  'â': 3074,
#  'İ': 2544,
#  'A': 2480,
#  'H': 2371,
#  'E': 2097,
#  'P': 1956,
#  '1': 1919,
#  'S': 1774,
#  'T': 1735,
#  'î': 1606,
#  '“': 1255,
#  '”': 1237,
#  '2': 1231,
#  '-': 1200,
#  '9': 1127,
#  'D': 1116,
#  ':': 1042,
#  'R': 992,
#  'C': 992,
#  'G': 954,
#  'Y': 947,
#  'û': 944,
#  'O': 878,
#  'F': 782,
#  'N': 685,
#  '‘': 655,
#  '0': 535,
#  '?': 441,
#  '3': 434,
#  'V': 424,
#  'Ş': 367,
#  ';': 342,
#  ')': 323,
#  'Ç': 303,
#  '(': 250,
#  '5': 246,
#  '4': 237,
#  'Z': 192,
#  '8': 184,
#  'Ö': 180,
#  '!': 171,
#  '7': 155,
#  'L': 150,
#  '6': 137,
#  'j': 122,
#  'Ü': 101,
#  '/': 99,
#  'U': 98,
#  'I': 59,
#  'J': 37,
#  'Â': 33,
#  'w': 25,
#  'W': 19,
#  'x': 3,
#  '\xa0': 3,
#  'Ğ': 3,
#  'é': 2,
#  'X': 1,
#  'q': 1,
#  '%': 1}

# %%
def hist_Nitems(items, values, N=20, x_angle=0):
    plt.figure(figsize=(10, 7))
    if N < 0:
        plt.bar(items, values)
    else:
        plt.bar(items[:N],values[:N])
    plt.ylabel("Relative Frequency (%)")
    plt.xticks(rotation=x_angle)
    plt.grid(True, axis='y', alpha=0.5)
    plt.show()

# %%
hist_Nitems(hist_chars, hist_freqs)

# %% [markdown]
# ## Word-level Tokenization

# %%
import re
clean_text = re.sub(r"\n{1,}", " ", text)
proc_text = re.split(r"\s+", clean_text)

# %%
# TOKEN_PATTERN = re.compile(r"[A-Za-zÇĞİÖŞÜçğıöşü]+|'[a-zçğıöşü]+|[^\w\s]", re.UNICODE)
words = {}
for w in proc_text:
    w = w.lower()
    if w in words.keys():
        words[w] += 1
    else:
        words[w] = 1

# %%
(sorted_words, w, w_f) = calculate_freq(words, replace_space=False)
sorted_words
# Out:
# {'ve': 6525,
#  'bir': 3909,
#  'bu': 2800,
#  'de': 927,
#  'ile': 905,
#  'da': 840,
#  'için': 766,
#  'olan': 749,
#  'olarak': 670,
#  'millî': 626,
#  'efendiler,': 622,
#  'bütün': 583,
#  'daha': 549,
#  'kadar': 541,
#  'paşa': 539,
#  'büyük': 444,
#  'gibi': 440,
#  'her': 434,
#  'o': 393,
#  'karşı': 392,
#  'olduğu': 389,
#  'ne': 385,
#  'bey': 379,
#  'ki,': 378,
#  'sonra,': 376,
#  'kabul': 373,
#  'bey,': 370,
#  'bulunan': 366,
#  'millet': 360,
#  'söz': 358,
#  'bey’in': 349,
#  'rauf': 332,
#  'sonra': 331,
#  'paşa’nın': 327,
#  'paşa,': 315,
#  'bazı': 302,
#  'en': 287,
#  'şu': 268,
#  'çok': 267,
#  'ilgili': 265,
#  'tarafından': 258,
#  'milletin': 256,
#  'olduğunu': 249,
#  'için,': 243,
#  'hükûmet': 234,
#  'şekilde': 232,
#  'uygun': 231,
#  'pek': 231,
#  'komutanı': 227,
#  'bundan': 225,
#  'iki': 222,
#  'genel': 217,
#  'i̇stanbul': 217,
#  'son': 208,
#  'i̇smet': 206,
#  'ali': 205,
#  'kolordu': 205,
#  'başka': 204,
#  'kendi': 203,
#  'önce': 203,
#  'içinde': 202,
#  'yeni': 201,
#  'üzere': 199,
#  'aynı': 192,
#  'böyle': 192,
#  'kemal': 190,
#  'yüksek': 188,
#  'bunun': 187,
#  'ileri': 185,
#  'birlikte': 184,
#  'benim': 180,
#  'hareket': 179,
#  'hey’et-i': 179,
#  'hiçbir': 178,
#  'önemli': 177,
#  'refet': 177,
#  'gün': 176,
#  'üzerinde': 176,
#  'de,': 174,
#  'ordu': 174,
#  'devam': 174,
#  'i̇stanbul’da': 172,
#  'kâzım': 169,
#  'i̇tilâf': 168,
#  'zaman': 168,
#  'yerine': 167,
#  'türk': 166,
#  'durumu': 165,
#  'ortaya': 165,
#  'cevap': 165,
#  'tarihli': 162,
#  'yalnız': 158,
#  'ben': 157,
#  'başkanı': 155,
#  'hemen': 155,
#  'rica': 153,
#  '1919': 152,
#  'meclis': 148,
#  'durum': 147,
#  'karar': 146,
#  'bunu': 145,
#  'üzerine': 143,
#  'özel': 142,
#  'telgraf': 141,
#  'mustafa': 140,
#  'veya': 140,
#  'gelen': 139,
#  'konusu': 139,
#  'fakat': 138,
#  'i̇stanbul’a': 136,
#  'da,': 135,
#  'yapılan': 134,
#  'doğru': 134,
#  'meclis’in': 134,
#  'buna': 132,
#  'etmek': 131,
#  'türlü': 131,
#  'bey’e': 131,
#  'cemâl': 131,
#  'olmak': 130,
#  'kesin': 128,
#  'nurettin': 128,
#  'değildir.': 127,
#  'bizim': 127,
#  'türkiye': 127,
#  'paşa’ya': 125,
#  'osmanlı': 124,
#  'onun': 124,
#  'özellikle': 123,
#  'ancak,': 123,
#  'askerî': 121,
#  'bana': 121,
#  'geri': 120,
#  'devlet': 119,
#  'gerçekten': 119,
#  'bile': 119,
#  'ethem': 119,
#  'gibi,': 118,
#  'üzere,': 118,
#  'adına': 118,
#  'tevfik': 116,
#  'yol': 115,
#  'gerek': 115,
#  'hükûmetin': 115,
#  'düşünce': 113,
#  'fakat,': 113,
#  'meclisi': 113,
#  'yunan': 112,
#  'düşman': 112,
#  'arasında': 111,
#  'yeniden': 111,
#  'gizli': 110,
#  'altında': 110,
#  'göre,': 110,
#  'harbiye': 110,
#  'tam': 110,
#  'kuva-yı': 109,
#  'ferit': 108,
#  'siyasî': 108,
#  'orada': 108,
#  'gerekli': 107,
#  'memleketin': 107,
#  'kendisine': 107,
#  'bize': 107,
#  'fuat': 107,
#  'ankara’ya': 105,
#  '1920': 105,
#  'mümkün': 104,
#  'idi.': 104,
#  'sivas': 104,
#  'barış': 104,
#  'iyi': 103,
#  'karabekir': 103,
#  'hiç': 102,
#  'birlikte,': 102,
#  'hükûmeti': 102,
#  'nasıl': 102,
#  'eden': 102,
#  'bağlı': 101,
#  'hakkında': 101,
#  'konuda': 101,
#  'elbette': 101,
#  'yoktur.': 101,
#  'milletvekili': 101,
#  'günü': 100,
#  'üç': 99,
#  '-': 99,
#  'kurulu': 99,
#  'erzurum': 98,
#  'ankara’da': 98,
#  'biz': 98,
#  'yer': 97,
#  'eylül': 97,
#  'bakanlar': 97,
#  'ilk': 96,
#  'teklif': 96,
#  'batı': 95,
#  'görev': 95,
#  'bilgi': 94,
#  'göre': 94,
#  'gereken': 94,
#  'ekim': 94,
#  'işgal': 93,
#  'açık': 93,
#  'tek': 92,
#  'vali': 92,
#  'birtakım': 91,
#  'nâzırı': 91,
#  'doğu': 90,
#  'gerçek': 90,
#  'şey': 90,
#  'ancak': 90,
#  'üzerine,': 88,
#  'başında': 88,
#  'vardı.': 87,
#  'şüphe': 87,
#  'derhal': 87,
#  'idare': 87,
#  'takdirde,': 87,
#  'i̇ngiliz': 86,
#  'emir': 85,
#  'önce,': 84,
#  'şimdi': 83,
#  'eski': 83,
#  'kasım': 83,
#  'meclis’te': 83,
#  'karşısında': 82,
#  'birçok': 82,
#  'duruma': 81,
#  'elde': 81,
#  'ilân': 81,
#  'görüş': 81,
#  'uzun': 80,
#  'hukuk': 80,
#  'doğrudan': 80,
#  'tümen': 80,
#  'millete': 80,
#  'diye': 80,
#  'kongre': 80,
#  'rıza': 80,
#  'herhangi': 78,
#  'yabancı': 78,
#  'resmî': 78,
#  'i̇stanbul’dan': 78,
#  'i̇zzet': 78,
#  'doğruya': 78,
#  'çünkü,': 78,
#  'bulunduğu': 77,
#  'edilen': 77,
#  'defa': 77,
#  'vatan': 77,
#  'tarihinde': 77,
#  'yine': 77,
#  'beş': 77,
#  'arz': 77,
#  'savunma': 77,
#  'ordunun': 76,
#  'biraz': 76,
#  'mart': 76,
#  'temsiliye': 76,
#  'burada': 75,
#  'gerekir.': 75,
#  'artık': 75,
#  'sami': 75,
#  'durumun': 74,
#  'bunların': 74,
#  'çeşitli': 74,
#  'yüce': 74,
#  'verdiği': 74,
#  'meclis-i': 74,
#  'olarak,': 73,
#  'yok': 73,
#  'haber': 73,
#  'bugün': 73,
#  'cephe': 73,
#  'halde,': 72,
#  'alan': 72,
#  'hilâfet': 71,
#  'müdafaa-i': 71,
#  'beri': 71,
#  'ondan': 71,
#  'sivas’ta': 71,
#  'diğer': 71,
#  'şifre': 71,
#  'vardır.': 71,
#  'sonunda': 70,
#  'davet': 70,
#  'başına': 70,
#  'yahya': 70,
#  'ateşkes': 69,
#  'halkın': 69,
#  '3.': 69,
#  'şöyle': 69,
#  'yerinde': 69,
#  'anadolu': 69,
#  'şeklinde': 69,
#  'bakanı': 69,
#  '1922': 69,
#  'i̇stanbul’daki': 68,
#  'konusunda': 68,
#  'güç': 68,
#  'saygıdeğer': 68,
#  'hazretleri’ne': 68,
#  'tespit': 68,
#  'bakımından': 67,
#  'i̇kinci': 67,
#  'beni': 67,
#  'teşkilât': 67,
#  'genelkurmay': 67,
#  'oldu.': 67,
#  'arif': 67,
#  'meclisi’nin': 67,
#  'ki:': 67,
#  'cephesi': 67,
#  'tedbirler': 66,
#  'dolayısıyla': 66,
#  'kendisi': 66,
#  '1-': 66,
#  'ettiği': 65,
#  'engel': 65,
#  'etti.': 65,
#  'ona': 65,
#  'cumhuriyet’in': 65,
#  'bugünkü': 64,
#  'cumhuriyet': 64,
#  'kurmay': 64,
#  'mecbur': 64,
#  'bununla': 64,
#  'acele': 64,
#  '2-': 64,
#  'kanun': 64,
#  'savaş': 63,
#  'memleket': 63,
#  'geçen': 63,
#  'verdiğim': 63,
#  'bekir': 63,
#  'yani': 63,
#  'kendisini': 63,
#  'birer': 62,
#  'verilen': 62,
#  'adı': 62,
#  'ben,': 62,
#  'sivas’a': 62,
#  'reşit': 62,
#  'eğer': 62,
#  'milleti': 61,
#  'dört': 61,
#  'millîye': 61,
#  'devletleri': 61,
#  'i̇şte': 61,
#  'komuta': 61,
#  'bizzat': 61,
#  'birkaç': 61,
#  'süre': 61,
#  'kısa': 61,
#  'paşa’yı': 61,
#  'yararlı': 61,
#  'dedi.': 61,
#  '1921': 61,
#  'halife': 60,
#  'zamanda': 60,
#  'belki': 60,
#  'kendisinin': 60,
#  'olmadığını': 60,
#  'meclis’e': 60,
#  'yalnız,': 59,
#  'an': 59,
#  'içine': 59,
#  'yerde': 59,
#  'ile,': 59,
#  'saltanat': 59,
#  'izin': 59,
#  'güven': 59,
#  'esasiye': 59,
#  'almak': 58,
#  'sonuç': 58,
#  'ankara': 58,
#  'kendilerine': 58,
#  'telgrafı': 58,
#  'teşkilât-ı': 58,
#  'on': 57,
#  'dikkate': 57,
#  'yakın': 57,
#  'vatanın': 57,
#  'sahip': 57,
#  'asla': 57,
#  'değer': 57,
#  'küçük': 57,
#  'kuvva-yı': 57,
#  'halk': 56,
#  'ifade': 56,
#  'onu': 56,
#  'değil,': 56,
#  'bizi': 56,
#  'konu': 56,
#  'vermek': 55,
#  'görüşme': 55,
#  'dahiliye': 55,
#  'bulunuyordu.': 55,
#  'etmiş': 55,
#  'iş': 55,
#  'kuvvet': 55,
#  'imza': 55,
#  'aldığı': 55,
#  'bakımdan': 55,
#  'valisi': 55,
#  'bey’i': 55,
#  'ederek': 55,
#  'fevzi': 55,
#  'bile,': 55,
#  'celâlettin': 55,
#  'halinde': 54,
#  'ele': 54,
#  'temmuz': 54,
#  'ederim.': 54,
#  'süvari': 54,
#  'dünya': 53,
#  'i̇slâm': 53,
#  'kötü': 53,
#  'hükûmeti’nin': 53,
#  'birinci': 53,
#  'yönetim': 52,
#  'parti': 52,
#  'ettim.': 52,
#  'temsil': 52,
#  'görevi': 52,
#  'açıkça': 52,
#  'başkanlığı‘na': 52,
#  'saldırıya': 51,
#  'amerikan': 51,
#  'ortadan': 51,
#  'ait': 51,
#  'saat': 51,
#  'başladı.': 51,
#  'merkez': 51,
#  'zaman,': 51,
#  'edildi.': 51,
#  'dışında': 51,
#  'açığa': 50,
#  'efendi': 50,
#  'kimseler': 50,
#  'padişah': 50,
#  'devletin': 50,
#  'takip': 50,
#  'ikinci': 50,
#  'dolayı': 50,
#  'hükûmete': 50,
#  '3-': 50,
#  'halkı': 49,
#  'öteki': 49,
#  'kadar,': 49,
#  'temel': 49,
#  'bildirdim.': 49,
#  'vekili': 49,
#  'yapılacak': 49,
#  'günü,': 49,
#  'salih': 49,
#  'başka,': 48,
#  'hattâ': 48,
#  'asıl': 48,
#  'ayrıca': 48,
#  'komutan': 48,
#  'ahmet': 48,
#  'devletleri’nin': 47,
#  'cemiyeti': 47,
#  'var': 47,
#  'biri': 47,
#  'bulunduğunu': 47,
#  'dolayısıyla,': 47,
#  'doğal': 47,
#  'i̇zmir': 47,
#  'teslim': 47,
#  'geldi.': 47,
#  'değildi.': 47,
#  'olağanüstü': 47,
#  'komutanlığı‘na': 47,
#  'aracılığıyla': 47,
#  'yaptığı': 46,
#  'tarihinde,': 46,
#  'rağmen,': 46,
#  'saldırı': 46,
#  'bilginize': 46,
#  'gerektiği': 46,
#  'ibaret': 46,
#  'alınan': 46,
#  'seçim': 46,
#  'edilmiş': 46,
#  'dışişleri': 46,
#  'kesinlikle': 45,
#  'albay': 45,
#  'gereği': 45,
#  'yeri': 45,
#  'zaten': 45,
#  'gereğini': 45,
#  'şimdiye': 45,
#  'olduğuna': 45,
#  'altına': 45,
#  'kimselerin': 45,
#  'tayin': 45,
#  'delegeler': 45,
#  'ocak': 45,
#  'devleti’nin': 44,
#  'aykırı': 44,
#  'kişi': 44,
#  'tercih': 44,
#  'hizmet': 44,
#  'uzak': 44,
#  '“bu': 44,
#  'kabine': 44,
#  'sağlamak': 43,
#  'hükûmet,': 43,
#  'başarı': 43,
#  'haziran': 43,
#  'olacağını': 43,
#  'i̇brahim': 43,
#  'ağustos': 43,
#  'fransız': 43,
#  'iç': 43,
#  'temas': 42,
#  'yandan': 42,
#  'olup': 42,
#  'durumda': 42,
#  'ciddî': 42,
#  'olacaktır.': 42,
#  'ise,': 42,
#  'şekli': 42,
#  'olması': 42,
#  'gelmiş': 42,
#  'hâkim': 42,
#  'olumlu': 42,
#  'yanlış': 42,
#  'aralık': 42,
#  'yaptığım': 41,
#  'değil': 41,
#  'dış': 41,
#  'mutlaka': 41,
#  'imkân': 41,
#  'takdir': 41,
#  'bey’den': 41,
#  'galip': 41,
#  'olmayan': 41,
#  'bey’in,': 41,
#  'dedim.': 41,
#  'çıkan': 41,
#  'gece': 41,
#  'hem': 41,
#  'selâhattin': 41,
#  'meydan': 41,
#  'jandarma': 41,
#  'temsiliye’nin': 41,
#  'birliği': 41,
#  'güvenilir': 40,
#  '1.': 40,
#  'fazla': 40,
#  'kuvvetleri': 40,
#  'şartlar': 40,
#  'şuydu:': 40,
#  'şifreli': 40,
#  'ortak': 40,
#  'ettiğim': 40,
#  'paşa’dan': 40,
#  'kara': 40,
#  'asker': 40,
#  'istifa': 40,
#  'i̇stanbul’un': 40,
#  'oldukları': 40,
#  'kabinenin': 40,
#  'verilmesi': 39,
#  'halde': 39,
#  'olursa': 39,
#  'göz': 39,
#  'gerçeği': 39,
#  'aleyhinde': 39,
#  'başkanlığı': 39,
#  'talimat': 39,
#  'meydana': 39,
#  'hazretleri’nin': 39,
#  'haklı': 39,
#  'olur.': 38,
#  'yardım': 38,
#  'bağımsız': 38,
#  'işaret': 38,
#  'güvenlik': 38,
#  'kararı': 38,
#  'karşı,': 38,
#  'yoktu.': 38,
#  'vasıf': 38,
#  'benimle': 38,
#  'işin': 38,
#  'demek': 38,
#  'sonucu': 38,
#  'içinde,': 38,
#  'görüşmek': 38,
#  'mi?': 38,
#  '4-': 38,
#  'konusundaki': 38,
#  'teklifi': 38,
#  '1920’de': 38,
#  'yolda': 37,
#  'sahibi': 37,
#  'olmadığı': 37,
#  'harekete': 37,
#  'yardımcı': 37,
#  'biz,': 37,
#  'binbaşı': 37,
#  'sadrazam': 37,
#  'sayın': 37,
#  'serbest': 37,
#  'karşılık': 36,
#  'tedbir': 36,
#  'manevî': 36,
#  'tehlikeli': 36,
#  'hangi': 36,
#  'yere': 36,
#  'görevden': 36,
#  'tekrar': 36,
#  'vakit': 36,
#  'aynen': 36,
#  'siz': 36,
#  'sonunda,': 36,
#  'paşa’nın,': 36,
#  'bildiri': 36,
#  'ana': 36,
#  'efendim.': 36,
#  'alay': 36,
#  'ispat': 36,
#  'kolaylıkla': 35,
#  'adında': 35,
#  'cemiyeti’nin': 35,
#  'kuvvetli': 35,
#  'sebep': 35,
#  'olsun': 35,
#  'bölgesinde': 35,
#  '15.': 35,
#  'sivil': 35,
#  'noktayı': 35,
#  'ederek,': 35,
#  'miydi?': 35,
#  '23': 35,
#  'aldığım': 35,
#  'telgrafla': 35,
#  'bizimle': 35,
#  'yola': 35,
#  'olduğundan,': 35,
#  'vermiş': 35,
#  'söyledim.': 35,
#  'geldiği': 35,
#  'tavsiye': 35,
#  '20': 35,
#  'bilinen': 35,
#  'görüşünü': 35,
#  'ankara’dan': 35,
#  'lozan': 35,
#  'ordusu': 34,
#  'takım': 34,
#  'görüşmeler': 34,
#  'sait': 34,
#  'yetki': 34,
#  'görevini': 34,
#  'size': 34,
#  'önem': 34,
#  'belli': 34,
#  'hazır': 34,
#  'verildi.': 34,
#  'yapmak': 34,
#  'şekil': 34,
#  'ise': 34,
#  'fiilî': 34,
#  'oysa,': 34,
#  'rumeli': 34,
#  'yüz': 34,
#  'seyyare': 34,
#  'açıktan': 33,
#  'kurmak': 33,
#  'hey’eti': 33,
#  'müslüman': 33,
#  'konya': 33,
#  'olduklarını': 33,
#  'tümeni': 33,
#  'olsun,': 33,
#  'hep': 33,
#  'aydın': 33,
#  'tamamen': 33,
#  'olacağı': 33,
#  'cevat': 33,
#  'edip': 33,
#  'cevabı': 33,
#  'bey’le': 33,
#  'olumsuz': 33,
#  'gönderilen': 33,
#  'madde': 33,
#  'komutanlığı': 33,
#  'general': 33,
#  'ettik.': 33,
#  'fethi': 33,
#  'başkomutanlık': 33,
#  '1923': 33,
#  'ağır': 32,
#  'trabzon': 32,
#  'sırasında': 32,
#  'hâlit': 32,
#  'sakınca': 32,
#  'üçüncü': 32,
#  'işe': 32,
#  'birlik': 32,
#  'ilişki': 32,
#  'ordusunun': 32,
#  'yolunda': 32,
#  'anlamak': 32,
#  'alınması': 32,
#  'memlekette': 32,
#  'kongresi': 32,
#  'nitelikte': 32,
#  'makine': 32,
#  'telgrafın': 32,
#  'göstermek': 32,
#  'kimse': 32,
#  'yıl': 32,
#  'hüseyin': 32,
#  'şükrü': 32,
#  'recep': 32,
#  'anlaşması': 31,
#  'memleketi': 31,
#  'kendilerini': 31,
#  'erzurum’da': 31,
#  'faaliyet': 31,
#  'esir': 31,
#  'milletinin': 31,
#  'öyle': 31,
#  'ay': 31,
#  'zorunda': 31,
#  'şeref': 31,
#  'emri': 31,
#  'olaylar': 31,
#  'sizin': 31,
#  'almış': 31,
#  'milletimizin': 31,
#  'silâhlı': 31,
#  'hakkı': 31,
#  'bildirilmesini': 31,
#  'eylül’de': 31,
#  'türkiye’nin': 31,
#  'milletvekillerinin': 31,
#  'kanunu': 31,
#  'karşısında,': 30,
#  'onların': 30,
#  'ayrı': 30,
#  'alarak': 30,
#  'teşkilâtı': 30,
#  'mektup': 30,
#  'toplantı': 30,
#  'kutsal': 30,
#  'resmen': 30,
#  'varlığını': 30,
#  '24': 30,
#  'zorunlu': 30,
#  'elverişli': 30,
#  'olduğunu,': 30,
#  'kanunun': 30,
#  'düşmanın': 30,
#  'meclis,': 30,
#  'mayıs': 29,
#  'yirmi': 29,
#  'kurtuluş': 29,
#  'örnek': 29,
#  'yapmaya': 29,
#  '20.': 29,
#  'yusuf': 29,
#  'gözden': 29,
#  'olmakla': 29,
#  '18': 29,
#  'kurulması': 29,
#  'olay': 29,
#  'kongresi’nin': 29,
#  'üyeleri': 29,
#  'verdi.': 29,
#  'kendini': 29,
#  'duygu': 29,
#  'hazretleri': 29,
#  'ettiler.': 29,
#  'hoca': 29,
#  'başkanlık': 29,
#  'bakımdan,': 29,
#  'para': 29,
#  'isteyen': 29,
#  'kerim': 29,
#  'nadi': 29,
#  'teklifinde:': 29,
#  'merkezi': 28,
#  'yaptıkları': 28,
#  'taşıyan': 28,
#  'kendiliğinden': 28,
#  'geçici': 28,
#  'etki': 28,
#  'edecek': 28,
#  'olduğum': 28,
#  'sonraki': 28,
#  'işleri': 28,
#  'gösterdiği': 28,
#  'konuşma': 28,
#  'işi': 28,
#  '13': 28,
#  'aşağıdaki': 28,
#  'necati': 28,
#  'ediyordu.': 28,
#  'mösyö': 28,
#  'konuyu': 28,
#  'sözler': 28,
#  'yunus': 28,
#  'şartları': 27,
#  'ermeni': 27,
#  'iken': 27,
#  'bunları': 27,
#  'tarih': 27,
#  'isyan': 27,
#  'dereceye': 27,
#  'bağımsızlığını': 27,
#  'milletçe': 27,
#  'arasında,': 27,
#  'bölge': 27,
#  'tayyar': 27,
#  '9': 27,
#  '5.': 27,
#  'benden': 27,
#  'yakından': 27,
#  'oradan': 27,
#  'fiilen': 27,
#  'işbirliği': 27,
#  'dolayı,': 27,
#  'şudur:': 27,
#  'bildirildi.': 27,
#  'önüne': 27,
#  'çerçevesinde': 27,
#  'sözleri': 27,
#  'anlam': 27,
#  'çözüme': 27,
#  'kaptan’ın': 27,
#  'sevres': 27,
#  'damat': 26,
#  'subay': 26,
#  'gecesi': 26,
#  'kurma': 26,
#  'kimseler,': 26,
#  'kamuoyunu': 26,
#  'yoksun': 26,
#  'komutanı,': 26,
#  'geniş': 26,
#  'kendilerinin': 26,
#  'verdiğimiz': 26,
#  'kararsızlık': 26,
#  'çalışma': 26,
#  'başlayan': 26,
#  'acı': 26,
#  'karşıya': 26,
#  'önceki': 26,
#  'aldım.': 26,
#  '22': 26,
#  'yeterli': 26,
#  'yapılması': 26,
#  'amasya’da': 26,
#  'kongrenin': 26,
#  'toplanması': 26,
#  'arkadaşları': 26,
#  'güzel': 26,
#  'yetkili': 26,
#  'etkili': 26,
#  'edilmesi': 26,
#  'adam': 26,
#  'verdim.': 26,
#  'altı': 26,
#  'halkının': 26,
#  'nokta': 26,
#  'etme': 26,
#  'kişinin': 26,
#  'başkan': 26,
#  'saygı': 26,
#  'konudaki': 26,
#  'bizden': 26,
#  'noktalar': 26,
#  'kuvvetlerini': 26,
#  'dedi': 26,
#  'teşkilâtın': 26,
#  'hâlâ': 26,
#  'kabinesi’nin': 26,
#  'ertesi': 25,
#  'maksatla': 25,
#  'korumak': 25,
#  'isterim.': 25,
#  'olduğundan': 25,
#  'bunda': 25,
#  'maddî': 25,
#  'önünde': 25,
#  'din': 25,
#  'kazanmış': 25,
#  'sonuna': 25,
#  'olduğumuz': 25,
#  'cafer': 25,
#  'üyelerinin': 25,
#  '8': 25,
#  'yapılmış': 25,
#  'bunlardan': 25,
#  'sırada,': 25,
#  'söyledi.': 25,
#  'günlerde': 25,
#  'yazdığı': 25,
#  'yolu': 25,
#  'edilecek': 25,
#  'yolunu': 25,
#  'aksi': 25,
#  'gösteren': 25,
#  'istediği': 25,
#  'olunur.': 25,
#  'tarafımızdan': 25,
#  'az': 25,
#  'i̇lk': 25,
#  'manda': 25,
#  'kişisel': 25,
#  'sürekli': 25,
#  'i̇lyas': 25,
#  'hamdi': 25,
#  'kanunu’nun': 25,
#  'avni': 25,
#  'alınmış': 24,
#  '2.': 24,
#  'tarihî': 24,
#  'dayanarak': 24,
#  'anadolu’da': 24,
#  'silâh': 24,
#  'etmeye': 24,
#  'halife’nin': 24,
#  'makamının': 24,
#  'bağımsızlık': 24,
#  'olsa': 24,
#  'geçmek': 24,
#  'yazdığım': 24,
#  'sözünü': 24,
#  'düzenli': 24,
#  '28': 24,
#  'noktaları': 24,
#  'yaptığımız': 24,
#  'büsbütün': 24,
#  'bin': 24,
#  'haberleşme': 24,
#  'bildiren': 24,
#  'bilgiler': 24,
#  'yasal': 24,
#  'mı': 24,
#  'herhalde': 24,
#  'vererek': 24,
#  'gelecek': 24,
#  'ısrar': 24,
#  'bildirdi.': 24,
#  '4': 24,
#  'olacak': 24,
#  'mi': 24,
#  'kaldırılması': 24,
#  'padişah’ın': 24,
#  'kalan': 24,
#  'i̇hsan': 24,
#  'i̇çişleri': 24,
#  'askerlik': 24,
#  'gazi': 24,
#  'gönderdiği': 23,
#  'olur': 23,
#  'haklarını': 23,
#  'noktada': 23,
#  'dolaylarında': 23,
#  'mehmet': 23,
#  'anadolu’nun': 23,
#  'haberdar': 23,
#  'bulunduğumuz': 23,
#  'anlamı': 23,
#  'olmuştur.': 23,
#  'güçlü': 23,
#  'fikir': 23,
#  'gerekiyordu.': 23,
#  'erzurum’a': 23,
#  'şimdiden': 23,
#  'yüzünden': 23,
#  'kararlar': 23,
#  '29': 23,
#  'baskı': 23,
#  'varlığı': 23,
#  'adını': 23,
#  'buraya': 23,
#  'tedbirleri': 23,
#  'üzerinden': 23,
#  'getirilmesi': 23,
#  'şimdilik': 23,
#  'telgrafta': 23,
#  'kurulmuş': 23,
#  'görüşleri': 23,
#  'razı': 23,
#  'güney': 23,
#  'yerlerde': 23,
#  'sözü': 23,
#  'şekliyle': 23,
#  'oraya': 23,
#  'varsa,': 23,
#  'çıkar': 23,
#  ...}

# %%
hist_Nitems(w, w_f, N=30, x_angle=90)

# %%
# Out:
# [3.948873436336898,
#  2.3656929138147027,
#  1.6945357274702397,
#  0.5610123640588972,
#  0.5476981547716311,
#  0.5083607182410719,
#  0.46357655972935846,
#  0.4532883070982891,
#  0.40547819193037876,
#  0.37884977335584646,
#  0.37642900803088897,
#  0.3528265461125535,
#  0.3322500408504149,
#  0.3274085102004999,
#  0.32619812753802113,
#  0.26870495107028086,
#  0.26628418574532337,
#  0.2626530377578872,
#  0.23784019317707294,
#  0.23723500184583357,
#  0.23541942785211545,
#  0.23299866252715795,
#  0.22936751453972173,
#  0.22876232320848236,
#  0.2275519405460036,
#  0.22573636655228552,
#  0.2239207925585674,
#  0.2215000272336099,
#  0.21786887924617368,
#  0.21665849658369493,
#  0.2112117746025406,
#  0.20092352197147129,
#  0.2003183306402319,
#  0.19789756531527442,
#  0.19063526934040198,
#  0.18276778203429014,
#  0.17368991206569956,
#  0.1621912767721515,
#  0.16158608544091213,
#  0.1603757027784334,
#  0.1561393634597578,
#  0.15492898079727907,
#  0.15069264147860345,
#  0.14706149349116723,
#  0.1416147715100129,
#  0.14040438884753415,
#  0.13979919751629477,
#  0.13979919751629477,
#  0.1373784321913373,
#  0.13616804952885855,
#  0.13435247553514043,
#  0.1313265188789436,
#  0.1313265188789436,
#  0.12587979689778925,
#  0.1246694142353105,
#  0.12406422290407113,
#  0.12406422290407113,
#  0.12345903157283175,
#  0.12285384024159238,
#  0.12285384024159238,
#  0.122248648910353,
#  0.12164345757911364,
#  0.1204330749166349,
#  0.11619673559795929,
#  0.11619673559795929,
#  0.11498635293548055,
#  0.1137759702730018,
#  0.11317077894176243,
#  0.1119603962792837,
#  0.11135520494804432,
#  0.10893443962308684,
#  0.10832924829184747,
#  0.10832924829184747,
#  0.10772405696060809,
#  0.10711886562936873,
#  0.10711886562936873,
#  0.10651367429812936,
#  0.10651367429812936,
#  0.10530329163565061,
#  0.10530329163565061,
#  0.10530329163565061,
#  0.10409290897317187,
#  0.10227733497945375,
#  0.10167214364821438,
#  0.10167214364821438,
#  0.10106695231697502,
#  0.10046176098573564,
#  0.09985656965449627,
#  0.09985656965449627,
#  0.09985656965449627,
#  0.09804099566077816,
#  0.09562023033582066,
#  0.0950150390045813,
#  0.09380465634210255,
#  0.09380465634210255,
#  0.0925942736796238,
#  0.09198908234838445,
#  0.08956831702342696,
#  0.08896312569218759,
#  0.08835793436094821,
#  0.08775274302970884,
#  0.0865423603672301,
#  0.08593716903599073,
#  0.08533197770475136,
#  0.08472678637351198,
#  0.08472678637351198,
#  0.08412159504227261,
#  0.08412159504227261,
#  0.08351640371103325,
#  0.0823060210485545,
#  0.08170082971731513,
#  0.08109563838607575,
#  0.08109563838607575,
#  0.08109563838607575,
#  0.07988525572359702,
#  0.07928006439235764,
#  0.07928006439235764,
#  0.07928006439235764,
#  0.07928006439235764,
#  0.07867487306111827,
#  0.07746449039863954,
#  0.07746449039863954,
#  0.07685929906740016,
#  0.07685929906740016,
#  0.07685929906740016,
#  0.07564891640492141,
#  0.07504372507368204,
#  0.07504372507368204,
#  0.07443853374244268,
#  0.07443853374244268,
#  0.07322815107996393,
#  0.07322815107996393,
#  0.07262295974872456,
#  0.07201776841748518,
#  0.07201776841748518,
#  0.07201776841748518,
#  0.07201776841748518,
#  0.07141257708624582,
#  0.07141257708624582,
#  0.07141257708624582,
#  0.07020219442376707,
#  0.0695970030925277,
#  0.0695970030925277,
#  0.0695970030925277,
#  0.06838662043004896,
#  0.06838662043004896,
#  0.06838662043004896,
#  0.06778142909880959,
#  0.06778142909880959,
#  0.06717623776757022,
#  0.06717623776757022,
#  0.06657104643633084,
#  0.06657104643633084,
#  0.06657104643633084,
#  0.06657104643633084,
#  0.06657104643633084,
#  0.06596585510509148,
#  0.0653606637738521,
#  0.0653606637738521,
#  0.0653606637738521,
#  0.06475547244261273,
#  0.06475547244261273,
#  0.06475547244261273,
#  0.06475547244261273,
#  0.06475547244261273,
#  0.06354508978013398,
#  0.06354508978013398,
#  0.06293989844889462,
#  0.06293989844889462,
#  0.06293989844889462,
#  0.06293989844889462,
#  0.06233470711765525,
#  0.06233470711765525,
#  0.061729515786415876,
#  0.061729515786415876,
#  0.061729515786415876,
#  0.061729515786415876,
#  0.061729515786415876,
#  0.0611243244551765,
#  0.0611243244551765,
#  0.0611243244551765,
#  0.0611243244551765,
#  0.0611243244551765,
#  0.0611243244551765,
#  0.060519133123937134,
#  0.05991394179269776,
#  0.05991394179269776,
#  0.05991394179269776,
#  0.05930875046145839,
#  0.05930875046145839,
#  0.05930875046145839,
#  0.05870355913021902,
#  0.05870355913021902,
#  0.05870355913021902,
#  0.058098367798979644,
#  0.058098367798979644,
#  0.05749317646774028,
#  0.05749317646774028,
#  0.0568879851365009,
#  0.0568879851365009,
#  0.0568879851365009,
#  0.0568879851365009,
#  0.056282793805261536,
#  0.056282793805261536,
#  0.05567760247402216,
#  0.05567760247402216,
#  0.055072411142782794,
#  0.055072411142782794,
#  0.05446721981154342,
#  0.05446721981154342,
#  0.05446721981154342,
#  0.05446721981154342,
#  0.05325683714906468,
#  0.05325683714906468,
#  0.052651645817825304,
#  0.052651645817825304,
#  0.052651645817825304,
#  0.052651645817825304,
#  0.052651645817825304,
#  0.05204645448658594,
#  0.05144126315534656,
#  0.05083607182410719,
#  0.05023088049286782,
#  0.05023088049286782,
#  0.05023088049286782,
#  0.05023088049286782,
#  0.04962568916162845,
#  0.04962568916162845,
#  0.04902049783038908,
#  0.04902049783038908,
#  0.04902049783038908,
#  0.04902049783038908,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.048415306499149706,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.047204923836670964,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04659973250543159,
#  0.04599454117419222,
#  0.04599454117419222,
#  0.04599454117419222,
#  0.04599454117419222,
#  0.04538934984295285,
#  0.04538934984295285,
#  0.04538934984295285,
#  0.04538934984295285,
#  0.04478415851171348,
#  0.04478415851171348,
#  0.04478415851171348,
#  0.04478415851171348,
#  0.04478415851171348,
#  0.04478415851171348,
#  0.04417896718047411,
#  0.04417896718047411,
#  0.04417896718047411,
#  0.04417896718047411,
#  0.04417896718047411,
#  0.04357377584923473,
#  0.04357377584923473,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.042968584517995366,
#  0.04236339318675599,
#  0.04236339318675599,
#  0.04236339318675599,
#  0.04236339318675599,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.041758201855516625,
#  0.04115301052427725,
#  0.04115301052427725,
#  0.04115301052427725,
#  0.04115301052427725,
#  0.04115301052427725,
#  0.04115301052427725,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.040547819193037876,
#  0.03994262786179851,
#  0.03994262786179851,
#  0.03994262786179851,
#  0.03994262786179851,
#  0.039337436530559135,
#  0.039337436530559135,
#  0.039337436530559135,
#  0.039337436530559135,
#  0.039337436530559135,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03873224519931977,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03812705386808039,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03752186253684102,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03691667120560165,
#  0.03631147987436228,
#  0.03631147987436228,
#  0.03631147987436228,
#  0.03631147987436228,
#  0.03631147987436228,
#  0.03631147987436228,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.03570628854312291,
#  0.035101097211883536,
#  0.035101097211883536,
#  0.035101097211883536,
#  0.035101097211883536,
#  0.035101097211883536,
#  0.035101097211883536,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.03449590588064417,
#  0.033890714549404795,
#  0.033890714549404795,
#  0.033890714549404795,
#  0.033890714549404795,
#  0.033890714549404795,
#  0.033890714549404795,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03328552321816542,
#  0.03268033188692605,
#  0.03268033188692605,
#  0.03268033188692605,
#  0.03268033188692605,
#  0.03268033188692605,
#  0.03207514055568668,
#  0.03207514055568668,
#  0.03207514055568668,
#  0.03207514055568668,
#  0.03207514055568668,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.03146994922444731,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030864757893207938,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.030259566561968567,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029654375230729196,
#  0.029049183899489822,
#  0.029049183899489822,
#  0.029049183899489822,
#  0.029049183899489822,
#  0.029049183899489822,
#  0.029049183899489822,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02844399256825045,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02783880123701108,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02723360990577171,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02662841857453234,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.02602322724329297,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.025418035912053594,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024812844580814224,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.024207653249574853,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.023602461918335482,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02299727058709611,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.02239207925585674,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021786887924617367,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.021181696593377996,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.020576505262138625,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019971313930899254,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.019366122599659884,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01876093126842051,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.01815573993718114,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.017550548605941768,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016945357274702397,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.016340165943463027,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015734974612223656,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.015129783280984284,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.014524591949744911,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  0.01391940061850554,
#  ...]

# %%
t = "Konya’da, Ankara’da, Batman’da ve Kayseri’de..."
TOKEN_PATTERN = re.compile(r"[A-Za-zÇĞİÖŞÜçğıöşü]+|'[a-zçğıöşü]+|[^\w\s]", re.UNICODE)
TOKEN_PATTERN.findall(t)
# Out:
# ['Konya',
#  '’',
#  'da',
#  ',',
#  'Ankara',
#  '’',
#  'da',
#  ',',
#  'Batman',
#  '’',
#  'da',
#  've',
#  'Kayseri',
#  '’',
#  'de',
#  '.',
#  '.',
#  '.']
