# %%
import re
from helpers import tr_lower

# %%
with open('data/turkce_isim_veri_seti/tr_isimler.txt', 'r', encoding='utf-8') as file:
    text = file.read()
text = tr_lower(text)
text = re.split(r'\n', text)
text
# Out:
# ['rukiye',
#  '',
#  'selami',
#  'mukaddes',
#  'şeyhmus',
#  'reyhan',
#  'rukyete',
#  'kuzey',
#  'sadı',
#  'nihal',
#  'sevin',
#  'gönül',
#  'selman',
#  'kamuran',
#  'recep',
#  'güzel',
#  'kibar',
#  'melike',
#  'başak',
#  'leymun',
#  'besim',
#  'yaprak',
#  'deniz',
#  'aras',
#  'eymen',
#  'muhteber',
#  'orhan',
#  'veli',
#  'nurcan',
#  'burak',
#  'murat',
#  'şeydo',
#  'harun',
#  'dilfiroz',
#  'atilla',
#  'serhat',
#  'fazıl',
#  'yılmaz',
#  'sonay',
#  'emine',
#  'gazal',
#  'güllü',
#  'turan',
#  'jiyan',
#  'malik',
#  'selçuk',
#  'mahfuz',
#  'çilem',
#  'belkız',
#  'serkan',
#  'fikran',
#  'esme',
#  'sevri',
#  'esra',
#  'besey',
#  'sitiye',
#  'eyyüp',
#  'fadile',
#  'mehmet',
#  'kübranur',
#  'salih',
#  'nesrihan',
#  'safa',
#  'sacide',
#  'yadiğar',
#  'savaş',
#  'esin',
#  'naziye',
#  'volkan',
#  'ozan',
#  'veziha',
#  'münevver',
#  'insaf',
#  'naif',
#  'hafi',
#  'nagihan',
#  'emirhan',
#  'mülkiyan',
#  'hatice',
#  'ayşenur',
#  'nuriye',
#  'nezir',
#  'metehan',
#  'turgut',
#  'umut',
#  'viyan',
#  'gafari',
#  'dilan',
#  'gülfem',
#  'ümiye',
#  'burhan',
#  'hayriye',
#  'enise',
#  'bedriye',
#  'elvan',
#  'şadiye',
#  'hira',
#  'menifa',
#  'zaide',
#  'nida',
#  'umay',
#  'nurgül',
#  'kinyas',
#  'ayni',
#  'maşite',
#  'nejla',
#  'gülçin',
#  'gazel',
#  'dilek',
#  'meslihan',
#  'önder',
#  'niğar',
#  'azize',
#  'nebi',
#  'mahsude',
#  'teslime',
#  'buğlem',
#  'hüseyin',
#  'revşan',
#  'rifat',
#  'tuğçe',
#  'nazim',
#  'sevli',
#  'reşat',
#  'mithat',
#  'ebubekir',
#  'ümran',
#  'serdar',
#  'hasibe',
#  'semra',
#  'medine',
#  'lina',
#  'rabia',
#  'neslihan',
#  'devran',
#  'esengül',
#  'gürgin',
#  'roza',
#  'ahmet',
#  'tevfik',
#  'ümit',
#  'irfan',
#  'ergül',
#  'elifnur',
#  'sema',
#  'fevzi',
#  'çiğdemnur',
#  'kasım',
#  'özay',
#  'fahriye',
#  'naim',
#  'serdal',
#  'kayhan',
#  'şehrivan',
#  'mikail',
#  'rifakat',
#  'buse',
#  'elisa',
#  'durdane',
#  'ismali',
#  'kanber',
#  'selver',
#  'halise',
#  'erdinç',
#  'hassari',
#  'bedrettin',
#  'göktuğ',
#  'perizade',
#  'cengiz',
#  'emrin',
#  'sultan',
#  'zühal',
#  'faik',
#  'nebahat',
#  'berrin',
#  'münüfe',
#  'rabiye',
#  'cihat',
#  'kubilay',
#  'gökce',
#  'bahattin',
#  'gülcan',
#  'şenol',
#  'fazilet',
#  'gıyaseddin',
#  'asuman',
#  'eray',
#  'telli',
#  'zelife',
#  'müyesser',
#  'yener',
#  'abdulgani',
#  'sevcan',
#  'telliye',
#  'bekir',
#  'miyase',
#  'suna',
#  'şakir',
#  'ayniye',
#  'doğa',
#  'besime',
#  'selviye',
#  'talha',
#  'ercan',
#  'haşim',
#  'birsen',
#  'ayfer',
#  'nülüfer',
#  'fulya',
#  'vedifa',
#  'okan',
#  'rüya',
#  'belkıs',
#  'hakan',
#  'özcan',
#  'zuleyha',
#  'ibrahim',
#  'sevgi',
#  'adalet',
#  'nezihat',
#  'mevlan',
#  'bilge',
#  'hülya',
#  'yüsra',
#  'nuran',
#  'sayime',
#  'bedia',
#  'cemal',
#  'gürbüz',
#  'rümeysa',
#  'nasife',
#  'cevahir',
#  'abuzer',
#  'cennet',
#  'muhabet',
#  'şeyda',
#  'erez',
#  'maruf',
#  'muzaffer',
#  'veysel',
#  'aziz',
#  'güner',
#  'sıddık',
#  'bahar',
#  'kerem',
#  'şefik',
#  'vedat',
#  'beyhan',
#  'saadet',
#  'fahrettin',
#  'asiye',
#  'dünya',
#  'seren',
#  'şimen',
#  'gökay',
#  'aysun',
#  'hamsi',
#  'asref',
#  'yakup',
#  'muhuttin',
#  'nazlıgül',
#  'kürşat',
#  'beşir',
#  'çağla',
#  'fatmatü',
#  'fadıl',
#  'pakize',
#  'selda',
#  'tayyar',
#  'selma',
#  'mahir',
#  'tenzile',
#  'ceylan',
#  'emeni',
#  'samine',
#  'selime',
#  'tekin',
#  'ecrin',
#  'ilhak',
#  'şerife',
#  'zerife',
#  'binnaz',
#  'hanifi',
#  'seven',
#  'nazife',
#  'hamza',
#  'nursel',
#  'bahri',
#  'birol',
#  'sabahat',
#  'kemal',
#  'ayişehan',
#  'canan',
#  'ülkü',
#  'şükran',
#  'sadiye',
#  'refika',
#  'kumru',
#  'devlet',
#  'fundagül',
#  'sümeyya',
#  'ayça',
#  'mümin',
#  'ertuğrul',
#  'alparslan',
#  'gülsüm',
#  'cihad',
#  'halil',
#  'nüjin',
#  'ferdi',
#  'halime',
#  'semiha',
#  'gülnihal',
#  'seher',
#  'mülkiye',
#  'melihan',
#  'duygu',
#  'basriye',
#  'güli',
#  'gülüstan',
#  'sergen',
#  'erdoğan',
#  'hilal',
#  'güzide',
#  'arize',
#  'semya',
#  'berivan',
#  'sena',
#  'samih',
#  'ilkay',
#  'berçem',
#  'naide',
#  'sevtap',
#  'fatih',
#  'rıdvan',
#  'şerefettin',
#  'ishak',
#  'belkis',
#  'şule',
#  'alpaslan',
#  'cevdet',
#  'kumsal',
#  'ergin',
#  'kazim',
#  'bilal',
#  'gökçe',
#  'sevda',
#  'begüm',
#  'hatun',
#  'gülten',
#  'filçan',
#  'besra',
#  'nüsret',
#  'mazhar',
#  'vesifa',
#  'zeriban',
#  'gülüzar',
#  'döndü',
#  'yazgül',
#  'hürriyet',
#  'abdülkerim',
#  'arzu',
#  'gül',
#  'ayhan',
#  'nebiye',
#  'aliye',
#  'islim',
#  'fatoş',
#  'ruhsar',
#  'mikkesime',
#  'müslüm',
#  'hamdi',
#  'nurşen',
#  'aşkı',
#  'nevzat',
#  'ferhat',
#  'hamdiye',
#  'sebahat',
#  'cezmi',
#  'çimen',
#  'bektaş',
#  'nadiye',
#  'lütfullah',
#  'memet',
#  'fikret',
#  'ayda',
#  'melehat',
#  'kayra',
#  'immihan',
#  'nazlı',
#  'abdulsamet',
#  'nesife',
#  'ruşan',
#  'nuh',
#  'ümeyye',
#  'beyzanur',
#  'zümra',
#  'faysal',
#  'celal',
#  'senem',
#  'berfin',
#  'rüzgar',
#  'neşe',
#  'mahire',
#  'şevket',
#  'maşide',
#  'metin',
#  'hevidar',
#  'kania',
#  'alper',
#  'gaffari',
#  'hanım',
#  'bertan',
#  'sevinç',
#  'pınar',
#  'abdulcebbar',
#  'esila',
#  'şenay',
#  'fahri',
#  'elif',
#  'yelda',
#  'mesude',
#  'inanç',
#  'süreyya',
#  'aycan',
#  'sıdıka',
#  'aşihan',
#  'ender',
#  'nedime',
#  'kamil',
#  'nisa',
#  'haci',
#  'tansel',
#  'rojin',
#  'sabrı',
#  'neviye',
#  'talip',
#  'mesut',
#  'müberra',
#  'şükrü',
#  'nesihat',
#  'çetin',
#  'zelal',
#  'hiranur',
#  'kadir',
#  'mahmut',
#  'sefa',
#  'çiçek',
#  'gülnur',
#  'gülhan',
#  'zennure',
#  'yüksel',
#  'kutay',
#  'dilara',
#  'sümeyra',
#  'aden',
#  'alev',
#  'ilhan',
#  'erol',
#  'diyaddin',
#  'ahret',
#  'uzay',
#  'seyhan',
#  'esmer',
#  'uğur',
#  'ayaz',
#  'emre',
#  'oğuz',
#  'ferit',
#  'tuğay',
#  'rabiha',
#  'özgül',
#  'fadime',
#  'servet',
#  'yasime',
#  'esranur',
#  'zülfü',
#  'gizem',
#  'gülay',
#  'berna',
#  'nimet',
#  'zeynal',
#  'nebile',
#  'sönmez',
#  'sabriye',
#  'goncagül',
#  'meliha',
#  'cevat',
#  'ilknur',
#  'osman',
#  'alaettin',
#  'begihan',
#  'şeyh',
#  'aysel',
#  'bediriye',
#  'hamri',
#  'seyfettin',
#  'tayide',
#  'nigar',
#  'kıymet',
#  'selahat',
#  'emrecan',
#  'keziban',
#  'aylin',
#  'yahya',
#  'bedir',
#  'latife',
#  'nebiha',
#  'hande',
#  'aybars',
#  'kamber',
#  'memnune',
#  'dursun',
#  'zühre',
#  'taha',
#  'sayme',
#  'bessey',
#  'ela',
#  'kaya',
#  'ilvan',
#  'ümmühan',
#  'mehet',
#  'ethem',
#  'alaaddin',
#  'immi',
#  'samet',
#  'hafure',
#  'nergis',
#  'necat',
#  'nihat',
#  'feyyaz',
#  'muazzez',
#  'tahire',
#  'hamse',
#  'hatayi',
#  'feride',
#  'ziney',
#  'sercan',
#  'sevim',
#  'nezahat',
#  'betül',
#  'mümtaz',
#  'berya',
#  'melisa',
#  'doğan',
#  'cavidan',
#  'saniye',
#  'nusret',
#  'eslem',
#  'gülbin',
#  'hasan',
#  'özgür',
#  'helin',
#  'ayten',
#  'dilforuz',
#  'sakine',
#  'dilşah',
#  'divan',
#  'gafure',
#  'müşerref',
#  'rojda',
#  'mulla',
#  'abdulmütalip',
#  'nedim',
#  'nisi',
#  'zekiye',
#  'besire',
#  'bünyamin',
#  'abidin',
#  'abdulhamit',
#  'vildan',
#  'bülent',
#  'imran',
#  'imam',
#  'nilgün',
#  'hakkı',
#  'mihreb',
#  'lamia',
#  'bedran',
#  'nuray',
#  'iltan',
#  'ebru',
#  'samime',
#  'abdülmecit',
#  'seyithan',
#  'zilan',
#  'sunay',
#  'büşra',
#  'ümmü',
#  'şirhan',
#  'naci',
#  'şemse',
#  'tülay',
#  'efnan',
#  'reşit',
#  'rumeysa',
#  'yonca',
#  'esen',
#  'cumali',
#  'mert',
#  'utku',
#  'necibe',
#  'nazime',
#  'şahizer',
#  'şenel',
#  'sümeyye',
#  'semine',
#  'bahreddin',
#  'pervin',
#  'zınnar',
#  'şahin',
#  'hediye',
#  'şehnaz',
#  'ergün',
#  'müyase',
#  'hadice',
#  'selin',
#  'erdi',
#  'abdullah',
#  'teyyar',
#  'hikmiye',
#  'hüsniye',
#  'gözde',
#  'selim',
#  'eylül',
#  'seda',
#  'necla',
#  'ada',
#  'tayfun',
#  'faruk',
#  'neziha',
#  'dilay',
#  'şengül',
#  'gürsel',
#  'zekeriye',
#  'bahaddin',
#  'musa',
#  'bilgin',
#  'kenan',
#  'enver',
#  'hasari',
#  'vasfiye',
#  'abubekir',
#  'fadil',
#  'selvihan',
#  'nazmiye',
#  'feyziye',
#  'şirin',
#  'kerim',
#  'yaşar',
#  'tuba',
#  'taner',
#  'zeliha',
#  'züleyhan',
#  'mehtap',
#  'muhammed',
#  'gurbet',
#  'zozan',
#  'vefa',
#  'tahsin',
#  'zehriban',
#  'nafia',
#  'aslan',
#  'hicret',
#  'nehir',
#  'imhan',
#  'emin',
#  'zuhriye',
#  'hüda',
#  'cem',
#  'hasine',
#  'kadirye',
#  'merve',
#  'makbule',
#  'mukadder',
#  'cenap',
#  'mine',
#  'esma',
#  'şehriban',
#  'züleyha',
#  'tahide',
#  'cahide',
#  'sabır',
#  'nazlıhan',
#  'isa',
#  'rahime',
#  'gülistan',
#  'haluk',
#  'hasarı',
#  'mercan',
#  'ismail',
#  'birsem',
#  'imihan',
#  'mürşide',
#  'fatıma',
#  'peyam',
#  'abdulhakim',
#  'ömer',
#  'miran',
#  'şermin',
#  'demet',
#  'mihriban',
#  'handan',
#  'suzan',
#  'hayat',
#  'şoray',
#  'aduli',
#  'sabri',
#  'nezihe',
#  'safiye',
#  'nur',
#  'gülşen',
#  'hazal',
#  'nurten',
#  'gülüsüm',
#  'resul',
#  'habib',
#  'mehdi',
#  'defne',
#  'hava',
#  'beyza',
#  'didarcan',
#  'mensure',
#  'maksude',
#  'güler',
#  'sedat',
#  'kaan',
#  'yeşim',
#  'adnan',
#  'abdulcenap',
#  'ebrar',
#  'aydın',
#  'sebiha',
#  'seçkin',
#  'halit',
#  'gülseren',
#  'media',
#  'aytün',
#  'mevlüde',
#  'saliha',
#  'nevgül',
#  'aysenem',
#  'hamiyet',
#  'yuşa',
#  'nazar',
#  'güley',
#  'ferda',
#  'sadık',
#  'sadet',
#  'yağmur',
#  'rıza',
#  'semyan',
#  'dilber',
#  'figen',
#  'cafer',
#  'günay',
#  'fatime',
#  'bircan',
#  'gülüşan',
#  'suphi',
#  'ihsan',
#  'gülabi',
#  'üsame',
#  'munire',
#  'sezer',
#  'gülsemin',
#  'sırrı',
#  'özgen',
#  'rakip',
#  'alperen',
#  'caner',
#  'neriman',
#  'şakire',
#  'emrah',
#  'hacer',
#  'zayde',
#  'ganime',
#  'berkan',
#  'rusgat',
#  'lütfü',
#  'tunahan',
#  'yalçın',
#  'öznur',
#  'rüveyda',
#  'fikriye',
#  'tuncer',
#  'fetli',
#  'kanime',
#  'nisanur',
#  'ayşehan',
#  'zuzan',
#  'devrim',
#  'perize',
#  'nezife',
#  'müzeyyen',
#  'perihan',
#  'ahsen',
#  'selvi',
#  'naciye',
#  'nisey',
#  'sıddıka',
#  'türkan',
#  'mahsum',
#  'nurhan',
#  'abdurahman',
#  'beyaz',
#  'sıdık',
#  'şahbettin',
#  'aygül',
#  'hanife',
#  'kalender',
#  'eda',
#  'sedrettin',
#  'evin',
#  'tevhide',
#  'zuhal',
#  'elmas',
#  'kadime',
#  'minever',
#  'zayide',
#  'müfide',
#  'mazlum',
#  'haydar',
#  'çiğdem',
#  'hayrettin',
#  'filiz',
#  'yıldız',
#  'yiğitalp',
#  'sinan',
#  'miray',
#  'naime',
#  'zehra',
#  'saime',
#  'hulusi',
#  'yunus',
#  'engin',
#  'erkan',
#  'talat',
#  'hasarri',
#  'kudret',
#  'lütfiye',
#  'gülter',
#  'alim',
#  'inan',
#  'yiğit',
#  'şeriban',
#  'arif',
#  'hasret',
#  'anıl',
#  'kazım',
#  'güldoğan',
#  'damla',
#  'naile',
#  'şaban',
#  'masal',
#  'didem',
#  'eyüp',
#  'ali',
#  'enez',
#  'asim',
#  'mebrure',
#  'nevin',
#  'günel',
#  'menşure',
#  'maile',
#  'tolga',
#  'oya',
#  'asya',
#  'nurdan',
#  'sibel',
#  'kamile',
#  'menekşe',
#  'cemile',
#  'şehmus',
#  'şemsiban',
#  'sezayir',
#  'nazan',
#  'aykut',
#  'tanju',
#  'rezzan',
#  'tulay',
#  'asliye',
#  'baran',
#  'şakibe',
#  'neysel',
#  'nurşan',
#  'serap',
#  'salime',
#  'rahşan',
#  'alya',
#  'gülbahar',
#  'yıldırım',
#  'regaib',
#  'yarel',
#  'çınar',
#  'gökhan',
#  'salihe',
#  'şerif',
#  'serpil',
#  'şefika',
#  'altun',
#  'yusuf',
#  'seydi',
#  'şevin',
#  'inci',
#  'ertan',
#  'tölün',
#  'radife',
#  'hüne',
#  'mahide',
#  'suat',
#  'behiye',
#  'nazire',
#  'sabirya',
#  'ezgi',
#  'zeynep',
#  'rahmi',
#  'şeyma',
#  'bozan',
#  'aşhan',
#  'poyraz',
#  'ayşe',
#  'melek',
#  'tekbir',
#  'kevser',
#  'emrullah',
#  'yadigar',
#  'öykü',
#  'erhan',
#  'onur',
#  'turgay',
#  'müge',
#  'arife',
#  'zeycan',
#  'hamit',
#  'zahir',
#  'basri',
#  'şahide',
#  'melik',
#  'müşeref',
#  'ziya',
#  'gülündan',
#  'serengül',
#  'habip',
#  'duriye',
#  'fatmanur',
#  'duru',
#  'gazi',
#  'ilhami',
#  'belinay',
#  'sayide',
#  'urkiye',
#  'sadam',
#  'enis',
#  'gulsana',
#  'nidanur',
#  'kiraz',
#  'büşranur',
#  'fazullah',
#  'mülkan',
#  'özge',
#  'sariye',
#  'atlas',
#  'adile',
#  'ferşit',
#  'besri',
#  'sait',
#  'yavuz',
#  'ravza',
#  'ipek',
#  'sara',
#  'mükail',
#  'nesilhan',
#  'arıf',
#  'bağdagül',
#  'dılovan',
#  'ayşegül',
#  'berat',
#  'nülifer',
#  'ayin',
#  'müjgan',
#  'buket',
#  'şilan',
#  'levent',
#  'azad',
#  'meral',
#  'bedirye',
#  'burcu',
#  'cümali',
#  'cihan',
#  'tuğbanur',
#  'abdulkadir',
#  'garip',
#  'aysima',
#  'ferhan',
#  'ışıl',
#  'aynur',
#  'yasin',
#  'abdurrahman',
#  'mediha',
#  ...]

# %%
new_names = []
for name in text:
    name_split = re.split(r'\s', name)
    new_names.append(name_split[0].strip())
new_names
# Out:
# ['rukiye',
#  '',
#  'selami',
#  'mukaddes',
#  'şeyhmus',
#  'reyhan',
#  'rukyete',
#  'kuzey',
#  'sadı',
#  'nihal',
#  'sevin',
#  'gönül',
#  'selman',
#  'kamuran',
#  'recep',
#  'güzel',
#  'kibar',
#  'melike',
#  'başak',
#  'leymun',
#  'besim',
#  'yaprak',
#  'deniz',
#  'aras',
#  'eymen',
#  'muhteber',
#  'orhan',
#  'veli',
#  'nurcan',
#  'burak',
#  'murat',
#  'şeydo',
#  'harun',
#  'dilfiroz',
#  'atilla',
#  'serhat',
#  'fazıl',
#  'yılmaz',
#  'sonay',
#  'emine',
#  'gazal',
#  'güllü',
#  'turan',
#  'jiyan',
#  'malik',
#  'selçuk',
#  'mahfuz',
#  'çilem',
#  'belkız',
#  'serkan',
#  'fikran',
#  'esme',
#  'sevri',
#  'esra',
#  'besey',
#  'sitiye',
#  'eyyüp',
#  'fadile',
#  'mehmet',
#  'kübranur',
#  'salih',
#  'nesrihan',
#  'safa',
#  'sacide',
#  'yadiğar',
#  'savaş',
#  'esin',
#  'naziye',
#  'volkan',
#  'ozan',
#  'veziha',
#  'münevver',
#  'insaf',
#  'naif',
#  'hafi',
#  'nagihan',
#  'emirhan',
#  'mülkiyan',
#  'hatice',
#  'ayşenur',
#  'nuriye',
#  'nezir',
#  'metehan',
#  'turgut',
#  'umut',
#  'viyan',
#  'gafari',
#  'dilan',
#  'gülfem',
#  'ümiye',
#  'burhan',
#  'hayriye',
#  'enise',
#  'bedriye',
#  'elvan',
#  'şadiye',
#  'hira',
#  'menifa',
#  'zaide',
#  'nida',
#  'umay',
#  'nurgül',
#  'kinyas',
#  'ayni',
#  'maşite',
#  'nejla',
#  'gülçin',
#  'gazel',
#  'dilek',
#  'meslihan',
#  'önder',
#  'niğar',
#  'azize',
#  'nebi',
#  'mahsude',
#  'teslime',
#  'buğlem',
#  'hüseyin',
#  'revşan',
#  'rifat',
#  'tuğçe',
#  'nazim',
#  'sevli',
#  'reşat',
#  'mithat',
#  'ebubekir',
#  'ümran',
#  'serdar',
#  'hasibe',
#  'semra',
#  'medine',
#  'lina',
#  'rabia',
#  'neslihan',
#  'devran',
#  'esengül',
#  'gürgin',
#  'roza',
#  'ahmet',
#  'tevfik',
#  'ümit',
#  'irfan',
#  'ergül',
#  'elifnur',
#  'sema',
#  'fevzi',
#  'çiğdemnur',
#  'kasım',
#  'özay',
#  'fahriye',
#  'naim',
#  'serdal',
#  'kayhan',
#  'şehrivan',
#  'mikail',
#  'rifakat',
#  'buse',
#  'elisa',
#  'durdane',
#  'ismali',
#  'kanber',
#  'selver',
#  'halise',
#  'erdinç',
#  'hassari',
#  'bedrettin',
#  'göktuğ',
#  'perizade',
#  'cengiz',
#  'emrin',
#  'sultan',
#  'zühal',
#  'faik',
#  'nebahat',
#  'berrin',
#  'münüfe',
#  'rabiye',
#  'cihat',
#  'kubilay',
#  'gökce',
#  'bahattin',
#  'gülcan',
#  'şenol',
#  'fazilet',
#  'gıyaseddin',
#  'asuman',
#  'eray',
#  'telli',
#  'zelife',
#  'müyesser',
#  'yener',
#  'abdulgani',
#  'sevcan',
#  'telliye',
#  'bekir',
#  'miyase',
#  'suna',
#  'şakir',
#  'ayniye',
#  'doğa',
#  'besime',
#  'selviye',
#  'talha',
#  'ercan',
#  'haşim',
#  'birsen',
#  'ayfer',
#  'nülüfer',
#  'fulya',
#  'vedifa',
#  'okan',
#  'rüya',
#  'belkıs',
#  'hakan',
#  'özcan',
#  'zuleyha',
#  'ibrahim',
#  'sevgi',
#  'adalet',
#  'nezihat',
#  'mevlan',
#  'bilge',
#  'hülya',
#  'yüsra',
#  'nuran',
#  'sayime',
#  'bedia',
#  'cemal',
#  'gürbüz',
#  'rümeysa',
#  'nasife',
#  'cevahir',
#  'abuzer',
#  'cennet',
#  'muhabet',
#  'şeyda',
#  'erez',
#  'maruf',
#  'muzaffer',
#  'veysel',
#  'aziz',
#  'güner',
#  'sıddık',
#  'bahar',
#  'kerem',
#  'şefik',
#  'vedat',
#  'beyhan',
#  'saadet',
#  'fahrettin',
#  'asiye',
#  'dünya',
#  'seren',
#  'şimen',
#  'gökay',
#  'aysun',
#  'hamsi',
#  'asref',
#  'yakup',
#  'muhuttin',
#  'nazlıgül',
#  'kürşat',
#  'beşir',
#  'çağla',
#  'fatmatü',
#  'fadıl',
#  'pakize',
#  'selda',
#  'tayyar',
#  'selma',
#  'mahir',
#  'tenzile',
#  'ceylan',
#  'emeni',
#  'samine',
#  'selime',
#  'tekin',
#  'ecrin',
#  'ilhak',
#  'şerife',
#  'zerife',
#  'binnaz',
#  'hanifi',
#  'seven',
#  'nazife',
#  'hamza',
#  'nursel',
#  'bahri',
#  'birol',
#  'sabahat',
#  'kemal',
#  'ayişehan',
#  'canan',
#  'ülkü',
#  'şükran',
#  'sadiye',
#  'refika',
#  'kumru',
#  'devlet',
#  'fundagül',
#  'sümeyya',
#  'ayça',
#  'mümin',
#  'ertuğrul',
#  'alparslan',
#  'gülsüm',
#  'cihad',
#  'halil',
#  'nüjin',
#  'ferdi',
#  'halime',
#  'semiha',
#  'gülnihal',
#  'seher',
#  'mülkiye',
#  'melihan',
#  'duygu',
#  'basriye',
#  'güli',
#  'gülüstan',
#  'sergen',
#  'erdoğan',
#  'hilal',
#  'güzide',
#  'arize',
#  'semya',
#  'berivan',
#  'sena',
#  'samih',
#  'ilkay',
#  'berçem',
#  'naide',
#  'sevtap',
#  'fatih',
#  'rıdvan',
#  'şerefettin',
#  'ishak',
#  'belkis',
#  'şule',
#  'alpaslan',
#  'cevdet',
#  'kumsal',
#  'ergin',
#  'kazim',
#  'bilal',
#  'gökçe',
#  'sevda',
#  'begüm',
#  'hatun',
#  'gülten',
#  'filçan',
#  'besra',
#  'nüsret',
#  'mazhar',
#  'vesifa',
#  'zeriban',
#  'gülüzar',
#  'döndü',
#  'yazgül',
#  'hürriyet',
#  'abdülkerim',
#  'arzu',
#  'gül',
#  'ayhan',
#  'nebiye',
#  'aliye',
#  'islim',
#  'fatoş',
#  'ruhsar',
#  'mikkesime',
#  'müslüm',
#  'hamdi',
#  'nurşen',
#  'aşkı',
#  'nevzat',
#  'ferhat',
#  'hamdiye',
#  'sebahat',
#  'cezmi',
#  'çimen',
#  'bektaş',
#  'nadiye',
#  'lütfullah',
#  'memet',
#  'fikret',
#  'ayda',
#  'melehat',
#  'kayra',
#  'immihan',
#  'nazlı',
#  'abdulsamet',
#  'nesife',
#  'ruşan',
#  'nuh',
#  'ümeyye',
#  'beyzanur',
#  'zümra',
#  'faysal',
#  'celal',
#  'senem',
#  'berfin',
#  'rüzgar',
#  'neşe',
#  'mahire',
#  'şevket',
#  'maşide',
#  'metin',
#  'hevidar',
#  'kania',
#  'alper',
#  'gaffari',
#  'hanım',
#  'bertan',
#  'sevinç',
#  'pınar',
#  'abdulcebbar',
#  'esila',
#  'şenay',
#  'fahri',
#  'elif',
#  'yelda',
#  'mesude',
#  'inanç',
#  'süreyya',
#  'aycan',
#  'sıdıka',
#  'aşihan',
#  'ender',
#  'nedime',
#  'kamil',
#  'nisa',
#  'haci',
#  'tansel',
#  'rojin',
#  'sabrı',
#  'neviye',
#  'talip',
#  'mesut',
#  'müberra',
#  'şükrü',
#  'nesihat',
#  'çetin',
#  'zelal',
#  'hiranur',
#  'kadir',
#  'mahmut',
#  'sefa',
#  'çiçek',
#  'gülnur',
#  'gülhan',
#  'zennure',
#  'yüksel',
#  'kutay',
#  'dilara',
#  'sümeyra',
#  'aden',
#  'alev',
#  'ilhan',
#  'erol',
#  'diyaddin',
#  'ahret',
#  'uzay',
#  'seyhan',
#  'esmer',
#  'uğur',
#  'ayaz',
#  'emre',
#  'oğuz',
#  'ferit',
#  'tuğay',
#  'rabiha',
#  'özgül',
#  'fadime',
#  'servet',
#  'yasime',
#  'esranur',
#  'zülfü',
#  'gizem',
#  'gülay',
#  'berna',
#  'nimet',
#  'zeynal',
#  'nebile',
#  'sönmez',
#  'sabriye',
#  'goncagül',
#  'meliha',
#  'cevat',
#  'ilknur',
#  'osman',
#  'alaettin',
#  'begihan',
#  'şeyh',
#  'aysel',
#  'bediriye',
#  'hamri',
#  'seyfettin',
#  'tayide',
#  'nigar',
#  'kıymet',
#  'selahat',
#  'emrecan',
#  'keziban',
#  'aylin',
#  'yahya',
#  'bedir',
#  'latife',
#  'nebiha',
#  'hande',
#  'aybars',
#  'kamber',
#  'memnune',
#  'dursun',
#  'zühre',
#  'taha',
#  'sayme',
#  'bessey',
#  'ela',
#  'kaya',
#  'ilvan',
#  'ümmühan',
#  'mehet',
#  'ethem',
#  'alaaddin',
#  'immi',
#  'samet',
#  'hafure',
#  'nergis',
#  'necat',
#  'nihat',
#  'feyyaz',
#  'muazzez',
#  'tahire',
#  'hamse',
#  'hatayi',
#  'feride',
#  'ziney',
#  'sercan',
#  'sevim',
#  'nezahat',
#  'betül',
#  'mümtaz',
#  'berya',
#  'melisa',
#  'doğan',
#  'cavidan',
#  'saniye',
#  'nusret',
#  'eslem',
#  'gülbin',
#  'hasan',
#  'özgür',
#  'helin',
#  'ayten',
#  'dilforuz',
#  'sakine',
#  'dilşah',
#  'divan',
#  'gafure',
#  'müşerref',
#  'rojda',
#  'mulla',
#  'abdulmütalip',
#  'nedim',
#  'nisi',
#  'zekiye',
#  'besire',
#  'bünyamin',
#  'abidin',
#  'abdulhamit',
#  'vildan',
#  'bülent',
#  'imran',
#  'imam',
#  'nilgün',
#  'hakkı',
#  'mihreb',
#  'lamia',
#  'bedran',
#  'nuray',
#  'iltan',
#  'ebru',
#  'samime',
#  'abdülmecit',
#  'seyithan',
#  'zilan',
#  'sunay',
#  'büşra',
#  'ümmü',
#  'şirhan',
#  'naci',
#  'şemse',
#  'tülay',
#  'efnan',
#  'reşit',
#  'rumeysa',
#  'yonca',
#  'esen',
#  'cumali',
#  'mert',
#  'utku',
#  'necibe',
#  'nazime',
#  'şahizer',
#  'şenel',
#  'sümeyye',
#  'semine',
#  'bahreddin',
#  'pervin',
#  'zınnar',
#  'şahin',
#  'hediye',
#  'şehnaz',
#  'ergün',
#  'müyase',
#  'hadice',
#  'selin',
#  'erdi',
#  'abdullah',
#  'teyyar',
#  'hikmiye',
#  'hüsniye',
#  'gözde',
#  'selim',
#  'eylül',
#  'seda',
#  'necla',
#  'ada',
#  'tayfun',
#  'faruk',
#  'neziha',
#  'dilay',
#  'şengül',
#  'gürsel',
#  'zekeriye',
#  'bahaddin',
#  'musa',
#  'bilgin',
#  'kenan',
#  'enver',
#  'hasari',
#  'vasfiye',
#  'abubekir',
#  'fadil',
#  'selvihan',
#  'nazmiye',
#  'feyziye',
#  'şirin',
#  'kerim',
#  'yaşar',
#  'tuba',
#  'taner',
#  'zeliha',
#  'züleyhan',
#  'mehtap',
#  'muhammed',
#  'gurbet',
#  'zozan',
#  'vefa',
#  'tahsin',
#  'zehriban',
#  'nafia',
#  'aslan',
#  'hicret',
#  'nehir',
#  'imhan',
#  'emin',
#  'zuhriye',
#  'hüda',
#  'cem',
#  'hasine',
#  'kadirye',
#  'merve',
#  'makbule',
#  'mukadder',
#  'cenap',
#  'mine',
#  'esma',
#  'şehriban',
#  'züleyha',
#  'tahide',
#  'cahide',
#  'sabır',
#  'nazlıhan',
#  'isa',
#  'rahime',
#  'gülistan',
#  'haluk',
#  'hasarı',
#  'mercan',
#  'ismail',
#  'birsem',
#  'imihan',
#  'mürşide',
#  'fatıma',
#  'peyam',
#  'abdulhakim',
#  'ömer',
#  'miran',
#  'şermin',
#  'demet',
#  'mihriban',
#  'handan',
#  'suzan',
#  'hayat',
#  'şoray',
#  'aduli',
#  'sabri',
#  'nezihe',
#  'safiye',
#  'nur',
#  'gülşen',
#  'hazal',
#  'nurten',
#  'gülüsüm',
#  'resul',
#  'habib',
#  'mehdi',
#  'defne',
#  'hava',
#  'beyza',
#  'didarcan',
#  'mensure',
#  'maksude',
#  'güler',
#  'sedat',
#  'kaan',
#  'yeşim',
#  'adnan',
#  'abdulcenap',
#  'ebrar',
#  'aydın',
#  'sebiha',
#  'seçkin',
#  'halit',
#  'gülseren',
#  'media',
#  'aytün',
#  'mevlüde',
#  'saliha',
#  'nevgül',
#  'aysenem',
#  'hamiyet',
#  'yuşa',
#  'nazar',
#  'güley',
#  'ferda',
#  'sadık',
#  'sadet',
#  'yağmur',
#  'rıza',
#  'semyan',
#  'dilber',
#  'figen',
#  'cafer',
#  'günay',
#  'fatime',
#  'bircan',
#  'gülüşan',
#  'suphi',
#  'ihsan',
#  'gülabi',
#  'üsame',
#  'munire',
#  'sezer',
#  'gülsemin',
#  'sırrı',
#  'özgen',
#  'rakip',
#  'alperen',
#  'caner',
#  'neriman',
#  'şakire',
#  'emrah',
#  'hacer',
#  'zayde',
#  'ganime',
#  'berkan',
#  'rusgat',
#  'lütfü',
#  'tunahan',
#  'yalçın',
#  'öznur',
#  'rüveyda',
#  'fikriye',
#  'tuncer',
#  'fetli',
#  'kanime',
#  'nisanur',
#  'ayşehan',
#  'zuzan',
#  'devrim',
#  'perize',
#  'nezife',
#  'müzeyyen',
#  'perihan',
#  'ahsen',
#  'selvi',
#  'naciye',
#  'nisey',
#  'sıddıka',
#  'türkan',
#  'mahsum',
#  'nurhan',
#  'abdurahman',
#  'beyaz',
#  'sıdık',
#  'şahbettin',
#  'aygül',
#  'hanife',
#  'kalender',
#  'eda',
#  'sedrettin',
#  'evin',
#  'tevhide',
#  'zuhal',
#  'elmas',
#  'kadime',
#  'minever',
#  'zayide',
#  'müfide',
#  'mazlum',
#  'haydar',
#  'çiğdem',
#  'hayrettin',
#  'filiz',
#  'yıldız',
#  'yiğitalp',
#  'sinan',
#  'miray',
#  'naime',
#  'zehra',
#  'saime',
#  'hulusi',
#  'yunus',
#  'engin',
#  'erkan',
#  'talat',
#  'hasarri',
#  'kudret',
#  'lütfiye',
#  'gülter',
#  'alim',
#  'inan',
#  'yiğit',
#  'şeriban',
#  'arif',
#  'hasret',
#  'anıl',
#  'kazım',
#  'güldoğan',
#  'damla',
#  'naile',
#  'şaban',
#  'masal',
#  'didem',
#  'eyüp',
#  'ali',
#  'enez',
#  'asim',
#  'mebrure',
#  'nevin',
#  'günel',
#  'menşure',
#  'maile',
#  'tolga',
#  'oya',
#  'asya',
#  'nurdan',
#  'sibel',
#  'kamile',
#  'menekşe',
#  'cemile',
#  'şehmus',
#  'şemsiban',
#  'sezayir',
#  'nazan',
#  'aykut',
#  'tanju',
#  'rezzan',
#  'tulay',
#  'asliye',
#  'baran',
#  'şakibe',
#  'neysel',
#  'nurşan',
#  'serap',
#  'salime',
#  'rahşan',
#  'alya',
#  'gülbahar',
#  'yıldırım',
#  'regaib',
#  'yarel',
#  'çınar',
#  'gökhan',
#  'salihe',
#  'şerif',
#  'serpil',
#  'şefika',
#  'altun',
#  'yusuf',
#  'seydi',
#  'şevin',
#  'inci',
#  'ertan',
#  'tölün',
#  'radife',
#  'hüne',
#  'mahide',
#  'suat',
#  'behiye',
#  'nazire',
#  'sabirya',
#  'ezgi',
#  'zeynep',
#  'rahmi',
#  'şeyma',
#  'bozan',
#  'aşhan',
#  'poyraz',
#  'ayşe',
#  'melek',
#  'tekbir',
#  'kevser',
#  'emrullah',
#  'yadigar',
#  'öykü',
#  'erhan',
#  'onur',
#  'turgay',
#  'müge',
#  'arife',
#  'zeycan',
#  'hamit',
#  'zahir',
#  'basri',
#  'şahide',
#  'melik',
#  'müşeref',
#  'ziya',
#  'gülündan',
#  'serengül',
#  'habip',
#  'duriye',
#  'fatmanur',
#  'duru',
#  'gazi',
#  'ilhami',
#  'belinay',
#  'sayide',
#  'urkiye',
#  'sadam',
#  'enis',
#  'gulsana',
#  'nidanur',
#  'kiraz',
#  'büşranur',
#  'fazullah',
#  'mülkan',
#  'özge',
#  'sariye',
#  'atlas',
#  'adile',
#  'ferşit',
#  'besri',
#  'sait',
#  'yavuz',
#  'ravza',
#  'ipek',
#  'sara',
#  'mükail',
#  'nesilhan',
#  'arıf',
#  'bağdagül',
#  'dılovan',
#  'ayşegül',
#  'berat',
#  'nülifer',
#  'ayin',
#  'müjgan',
#  'buket',
#  'şilan',
#  'levent',
#  'azad',
#  'meral',
#  'bedirye',
#  'burcu',
#  'cümali',
#  'cihan',
#  'tuğbanur',
#  'abdulkadir',
#  'garip',
#  'aysima',
#  'ferhan',
#  'ışıl',
#  'aynur',
#  'yasin',
#  'abdurrahman',
#  'mediha',
#  ...]

# %%
new_names = list(set(new_names))
len(new_names)
# Out:
# 1176

# %%
# # Save the new names
# with open('data/turkce_isim_veri_seti/tr_isimler2.txt', 'w', encoding='utf-8') as file:
#     for line in new_names:
#         file.write(line + '\n')
